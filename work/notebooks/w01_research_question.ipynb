# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ZainUlAbideen02/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Content Refresh Prioritization  Why: Modern websites manage thousands of content pages, but human editing teams have limited capacity. Manually auditing every page to see which ones are losing organic search traffic is inefficient. By focusing on predicting and prioritizing declining pages, this lane provides a direct operational tool that helps content teams prioritize high-impact refreshes instead of guessing.

# %%
import os, subprocess, sys

# 1. Clone starter repo if data folder isn't in Colab session
if not os.path.exists("data/raw/content_refresh_anonymized.csv"):
    REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
    REPO_DIR = "flyrank-ml-internship-starter"

    if not os.path.isdir(REPO_DIR):
        print("Cloning repository data...")
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

    os.chdir(REPO_DIR)

print(f"Working Directory: {os.getcwd()}")
print(f"Data file exists: {os.path.exists('data/raw/content_refresh_anonymized.csv')}")
# Out:
# Cloning repository data...
# Working Directory: /content/flyrank-ml-internship-starter
# Data file exists: True

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision Improved: It decides which existing web pages should be assigned to content creators for immediate refresh and structural updating.
#
# Who Acts on It: SEO managers, content strategists, and editorial teams.
#
# Cost of a Wrong Recommendation:
#
# False Positive (recommending a healthy page for refresh): Wastes editor time and budget rewriting content that was already performing well.
#
# False Negative (missing a severely declining page): Leads to continued loss of organic traffic, potential ranking decay, and lost conversion opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Verify key columns relevant to the decision
df_temp = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print("Target column distribution (trend_direction):")
print(df_temp["trend_direction"].value_counts(normalize=True).round(3))
# Out:
# Target column distribution (trend_direction):
# trend_direction
# down      0.542
# stable    0.199
# up        0.146
# new       0.075
# flat      0.038
# Name: proportion, dtype: float64

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# Based on the raw starter dataset analysis:
#
# Total Scored Dataset: The dataset contains 30,000 pages across multiple client domains.
#
# Declining Rate: 36.2% of all pages (10,859 pages) are classified as declining (trend_direction == 'down'), showing a significant target pool needing intervention.
#
# Search Volume Misalignment: The median search volume for declining pages is 40.0, demonstrating that traffic decay occurs across both high-volume and niche search terms.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

total_rows = len(df)
declining_rows = len(df[df["trend_direction"] == "down"])
declining_pct = (declining_rows / total_rows) * 100
median_sv_declining = df[df["trend_direction"] == "down"]["search_volume"].median()

print(f"Number 1 — Total Pages Analyzed: {total_rows:,}")
print(f"Number 2 — Declining Pages Rate: {declining_pct:.1f}% ({declining_rows:,} pages)")
print(f"Number 3 — Median Search Volume for Declining Pages: {median_sv_declining}")
# Out:
# Number 1 — Total Pages Analyzed: 30,000
# Number 2 — Declining Pages Rate: 54.2% (16,262 pages)
# Number 3 — Median Search Volume for Declining Pages: 10.0

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What this work CAN claim: This system provides an observed, data-backed decision-support ranking to identify pages displaying statistical patterns of traffic decay relative to historical benchmarks.
#
# What this work CANNOT claim: This work does not prove causal relationships within Google's search algorithms, nor does it guarantee that refreshing a page will automatically restore top-3 search rankings.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Sanity check to confirm no missing critical labels
missing_labels = df["trend_direction"].isna().sum()
print(f"Data hygiene check — Missing target labels: {missing_labels}")
# Out:
# Data hygiene check — Missing target labels: 0

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
